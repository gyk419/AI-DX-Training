# %%
a= 10+2
a
# Out:
# 12

# %%
b= "hello"

# %%
c= "world"

# %%
c= b+c
c
# Out:
# 'helloworld'

# %%
type(c)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
a= 2.5
type(a)
# Out:
# float

# %%
string2int = '123'
type(string2int)
# Out:
# str

# %%
int(string2int)
# Out:
# 123

# %%
type(int(string2int))
# Out:
# int

# %%
list=[1,3,5,7,9,11,13,15]
list
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]

# %%
len(list)
# Out:
# 8

# %%
for i in range(len(list)):
  print(list[i])
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15

# %%
list[-1]
# Out:
# 15

# %%
list[2:6]
# Out:
# [5, 7, 9, 11]

# %%
list[::]
# Out:
# [1, 3, 5, 7, 9, 11, 13, 15]

# %%
list[:-1]
# Out:
# [1, 3, 5, 7, 9, 11, 13]

# %%
import pandas as pd

df_red = pd.read.csv('')
